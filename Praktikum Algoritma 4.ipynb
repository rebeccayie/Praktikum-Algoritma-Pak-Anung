# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeccayie/Praktikum-Algoritma-Pak-Anung/blob/main/Praktikum%20Algoritma%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Rebecca Gabriella Blessing Sihite
# 065002500042
# Program Perulangan

for i in range(7, 0, -1):
  print(str(i) * i)
# Out:
# 7777777
# 666666
# 55555
# 4444
# 333
# 22
# 1

# %%
# Rebecca Gabriella Blessing Sihite
# 065002500042
# Program Menentukan Jumlah Hari dalam Bulan

ulang = "y"

while ulang.lower() == "y":
    bulan = int(input("Masukkan nomor bulan (1-12): "))
    tahun = int(input("Masukkan tahun: "))

    if bulan in [1, 3, 5, 7, 8, 10, 12]:
        hari = 31
    elif bulan in [4, 6, 9, 11]:
        hari = 30
    elif bulan == 2:
        # Cek tahun kabisat
        if (tahun % 4 == 0 and tahun % 100 != 0) or (tahun % 400 == 0):
            hari = 29
        else:
            hari = 28
    else:
        print("Nomor bulan tidak valid!")
        hari = None

    if hari:
        print(f"Jumlah hari pada bulan {bulan} tahun {tahun} adalah {hari} hari.")

    ulang = input("Apakah ingin menghitung lagi? (y/n): ")

print("Program selesai.")
# Out:
# Masukkan nomor bulan (1-12): 2
# Masukkan tahun: 2020
# Jumlah hari pada bulan 2 tahun 2020 adalah 29 hari.
# Apakah ingin menghitung lagi? (y/n): y
# Masukkan nomor bulan (1-12): 5
# Masukkan tahun: 2015
# Jumlah hari pada bulan 5 tahun 2015 adalah 31 hari.
# Apakah ingin menghitung lagi? (y/n): n
# Program selesai.
