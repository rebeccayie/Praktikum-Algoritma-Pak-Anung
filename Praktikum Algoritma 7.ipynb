# %% [markdown]
# <a href="https://colab.research.google.com/github/rebeccayie/Praktikum-Algoritma-Pak-Anung/blob/main/Praktikum%20Algoritma%207.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Rebecca Gabriella Blessing Sihite
# 065002500042
# Program Menghitung Nilai Prima

def cek_prima(x):
    if x <= 1:
        return False
    if x == 2:
        return True
    for i in range(2, x):
        if x % i == 0:
            return False
    return True

def tampil_hasil_prima(angka, status_prima):
    if status_prima:
        print(f"{angka} adalah bilangan Prima")
    else:
        print(f"{angka} bukanlah bilangan Prima")

angka_input = int(input("Masukkan Angka:"))
status = cek_prima(angka_input)
tampil_hasil_prima(angka_input, status)
# Out:
# Masukkan Angka:3
# 3 adalah bilangan Prima

# %%
# Rebecca Gabriella Blessing Sihite
# 065002500042
# Program Menghitung Output

def dapatkan_akhiran_ordinal(n):
    if n == 0:
        return 'th'

    dua_digit_terakhir = n% 100
    if 10 <= dua_digit_terakhir <= 20:
        return 'th'

    digit_terakhir = n % 10
    if digit_terakhir == 1:
            akhiran ='st'
    elif digit_terakhir == 2:
            akhiran = 'nd'
    elif digit_terakhir == 3:
            akhiran = 'rd'
    else:
        akhiran = 'th'
    return akhiran

print("Ordinal Number")
print("ketik 0 untuk menghentikan program.")

while True:
    angka = int(input("Masukkan angka:"))
    suffix = dapatkan_akhiran_ordinal(angka)
    print(f"({angka}, '{suffix}')")

    if angka == 0:
        print("Terima kasih telah menggunakan program saya.")
        break
# Out:
# Ordinal Number
# ketik 0 untuk menghentikan program.
# Masukkan angka:1
# (1, 'st')
# Masukkan angka:2
# (2, 'nd')
# Masukkan angka:3
# (3, 'rd')
# Masukkan angka:0
# (0, 'th')
# Terima kasih telah menggunakan program saya.
